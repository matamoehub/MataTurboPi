# %% [markdown]
# # Lesson 01 – Robot Demo (Level 1)
#
# ## Goal
# Use basic robot movement to complete the **cups challenge**.
#
# You are **not** changing robot libraries in this lesson.
# Your focus is:
# - Running code
# - Observing behaviour
# - Adjusting values
# - Solving the physical challenge with cups
#
# ---
#
# ## Safety first
# - Keep hands clear of the robot while it is moving
# - If something goes wrong, stop the robot immediately

# %%
# Import robot movement helpers
from robot_moves import forward, turn_left, stop

# %% [markdown]
# ## Exercise: Move forward
#
# Run the cell below and observe how far the robot moves.

# %%
forward(1.0)

# %% [markdown]
# ## Exercise: Turn left
#
# The robot can rotate on the spot.

# %%
turn_left(0.5)

# %% [markdown]
# ## Combining movements
#
# Robots follow instructions **in order**.
# Try this sequence.

# %%
forward(1.0)
turn_left(0.5)
forward(1.0)

# %% [markdown]
# ## Cups Challenge
#
# Your task:
#
# 1. Place cups on the floor to form a simple obstacle or target
# 2. Use **forward** and **turn_left**
# 3. Adjust timing values to:
#    - drive around cups
#    - stop near a target
#    - line up carefully
#
# ### Rules
# - You may only change numbers (time values)
# - Do not edit robot libraries
# - Test often and make small changes
#
# There is no single correct solution.

# %%
# Emergency stop (run if needed)
stop()
