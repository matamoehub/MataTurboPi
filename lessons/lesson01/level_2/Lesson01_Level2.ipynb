# %% [markdown]
# # Lesson 1 — Level 2: Build your own robot_moves library
#
# You will edit: `lessons/lib/robot_moves.py`
#
# Complete these methods:
# - `backward()`
# - `move_right()`
# - `spin_right()`
#
# This file becomes **your** movement library for future lessons.

# %%
from pathlib import Path
import sys, importlib

ROOT = Path.cwd().resolve()
LESSONS_LIB = ROOT / 'lessons' / 'lib'
COMMON_LIB  = ROOT / 'common' / 'lib'

for p in [LESSONS_LIB, COMMON_LIB]:
    if str(p) not in sys.path:
        sys.path.insert(0, str(p))

import robot_moves as student_moves
importlib.reload(student_moves)

print('Student robot_moves loaded from:', student_moves.__file__)
rm = student_moves.RobotMoves(base_speed=220, rate_hz=30)
print('RobotMoves ready ✅')

# %% [markdown]
# ## Working examples (should work now)
# - horn
# - forward
# - move_left
# - spin_left

# %%
rm.horn()
rm.forward(0.5)
rm.move_left(0.5)
rm.spin_left(0.4)
rm.horn()

# %% [markdown]
# ## Now implement the TODO methods
#
# Edit `lessons/lib/robot_moves.py` then run the next cell to reload.

# %%
import importlib
import robot_moves as student_moves
importlib.reload(student_moves)
rm = student_moves.RobotMoves(base_speed=220, rate_hz=30)
print('Reloaded ✅')

# %% [markdown]
# ## Tests (should fail until you finish)

# %%
rm.backward(0.6)
rm.move_right(0.6)
rm.spin_right(0.5)
rm.horn()
print('Level 2 complete ✅')
