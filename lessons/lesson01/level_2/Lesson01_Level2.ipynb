# %% [markdown]
# # Lesson 1 — Level 2 (Two cups)
#
# Setup: two cups like this:
#
# `*      *`
#
# Goal: drive a path that goes around both cups.
#
# ## Important
# This lesson uses **your student library**:
#
# - `lessons/lib/student_robot_moves.py`
#
# You must complete:
# - `backward(seconds)`
# - `move_right(seconds)`
# - `spin_right(seconds)`
#
# If you get stuck, ask a tutor to show the *pattern* (not the full answer).

# %%
# Bootstrap (shared)
from lesson_loader import setup
setup()

# %% [markdown]
# ## Movement tutorial (Jupyter)
# Read: `Movement_Tutorial.md` in this same folder.
#
# In notebook cells use:
# ```python
# from lesson_loader import setup
# setup()
# import student_robot_moves as srm
# ```

# %%
import time
import student_robot_moves as srm

print('Loaded student library:', srm.__file__)

# quick smoke test of the functions that already work
srm.forward(0.5)
time.sleep(0.15)
srm.turn_left(0.4)
time.sleep(0.15)
srm.drift_left(0.6, turn_blend=0.55)
time.sleep(0.15)
print('Smoke test done')

# %% [markdown]
# ## Your two-cup plan
#
# Use your student functions to make a clean path.
#
# Tip: do it in small chunks. Run one chunk. Adjust. Then add more.

# %% [markdown]
# ## Challenge: Tune Drift Left (2 variables)
# Use your student function: `srm.drift_left(seconds, turn_blend=...)`.
#
# - `seconds`: drift time
# - `turn_blend`: curve strength (`0.0` = more sideways, `1.0` = more turning)
#
# Goal: find the best settings to pass between two cups cleanly.

# %%
# Drift tuning challenge
drift_seconds = 0.9
turn_blend = 0.55

print(f'Testing srm.drift_left(seconds={drift_seconds}, turn_blend={turn_blend})')
srm.drift_left(drift_seconds, turn_blend=turn_blend)

# %%
# TODO: build your plan here

# Example structure:
# srm.forward(0.8)
# srm.drift_left(0.9)
# srm.move_right(0.7)
# srm.spin_right(0.5)
# srm.backward(0.4)

print('Your turn — build the plan')
