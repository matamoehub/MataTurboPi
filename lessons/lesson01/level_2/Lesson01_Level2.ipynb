# %% [markdown]
# # Lesson 01 – Robot Demo (Level 2)
#
# ## Goal
# In this lesson you will **complete the robot movement library**.
#
# You are given a robot that can already:
# - move forward
# - turn left
# - drift left
# - move left
# - move diagonally left
#
# You must:
# - read existing code
# - complete missing functions
# - test each movement on the real robot
#
# ---
#
# This is how real robotics teams work.

# %%
# Load the STUDENT movement library
import sys
sys.path.insert(0, "student_lib")

import robot_moves

# %% [markdown]
# ## Test the provided movements
#
# These functions already work.

# %%
robot_moves.forward()
robot_moves.turn_left()
robot_moves.drift_left()
robot_moves.move_left()
robot_moves.diagonal_left()

# %% [markdown]
# ## Your task
#
# Open:
#
# `student_lib/robot_moves.py`
#
# You will find functions that are incomplete.
#
# You need to complete:
# - backward
# - turn_right
# - drift_right
# - move_right
# - diagonal_right
#
# Use the **left versions** as examples.

# %% [markdown]
# ## Testing your work
#
# After completing each function, test it here.

# %%
# Uncomment and test as you complete each function

# robot_moves.backward()
# robot_moves.turn_right()
# robot_moves.drift_right()
# robot_moves.move_right()
# robot_moves.diagonal_right()

# %% [markdown]
# ## Challenge
#
# Create a full movement sequence using:
# - left + right
# - forward + backward
# - diagonal moves
#
# Try to navigate around the cups from Level 1,
# but this time using your own completed library.
