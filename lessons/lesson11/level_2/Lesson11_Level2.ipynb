# %% [markdown]
# # Lesson 11 — Level 2 (Two cups)
#
# Goal: build and test a movement sequence to drive around **two cups**.
#
# This mirrors Lesson 1 Level 2, but uses the V2 object API.
#
# The important idea is still the same: test one movement at a time, then build a sequence.
# Do not start with a long full run. Tune the parts first.

# %%
from lesson_header import *
show_v2_status()
myRobot = bot(base_speed=300)

# %% [markdown]
# ## Movement tutorial
# Use short forward and turn tests to estimate how the robot will move around two cups.
#
# You are trying to answer questions like:
# - how far is a 0.3 second forward move?
# - how sharp is a 0.25 second turn?
# - where do you need drift instead of a normal turn?

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.move.forward(0.3)
myRobot.move.turn_left(0.25)
myRobot.stop()

# %% [markdown]
# ## Your two-cup plan
# Plan the sequence before you code it.
#
# Think about:
# - how the robot passes cup 1
# - what changes before cup 2
# - which move needs the most tuning
# - where the robot should finish
#
# A two-cup challenge is really a planning problem. The code is short. The tuning is the hard part.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

# Build your two-cup plan here.
# Use short tests first, then a full sequence.

myRobot.stop()
