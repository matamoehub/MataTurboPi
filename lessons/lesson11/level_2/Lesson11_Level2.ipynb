# %% [markdown]
# # Lesson 11 — Level 2 (Two cups)
#
# Setup: two cups like this:
#
# `*      *`
#
# Goal: build your own movement library and drive around both cups.
#
# ## Important
# This lesson uses **your student library**:
#
# - `lessons/lib/`myRobot.move`.py`
#
# Reference functions (already provided):
# - `forward(seconds, speed=None)`
# - `move_left(seconds, speed=None)`
# - `turn_left(seconds, speed=None)`
# - `drift_left(seconds, speed=None, turn_blend=...)`
#
# You must implement:
# - `backward(seconds, speed=None)`
# - `move_right(seconds, speed=None)`
# - `turn_right(seconds, speed=None)`
#
# Challenge extension:
# - `drift_right(seconds, speed=None, turn_blend=...)`

# %%
from lesson_header import *
show_v2_status()
myRobot = bot(base_speed=300)

# %% [markdown]
# ## Movement tutorial
# Read: `Movement_Tutorial.md` in this same folder.
#
# Focus in this lesson: understand wheel patterns from these reference moves:
# - `forward`
# - `move_left`
# - `turn_left`
# - `drift_left`
#
# Then apply the same pattern logic to implement your TODO functions.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.move.forward(0.3)
myRobot.move.turn_left(0.25)
myRobot.stop()

# %% [markdown]
# ## Your two-cup plan
#
# Use your student functions to make a clean path.
#
# Tip: do it in small chunks. Run one chunk. Adjust. Then add more.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

# Build your two-cup plan here.
# Use short tests first, then a full sequence.

myRobot.stop()
