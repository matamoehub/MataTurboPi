# %% [markdown]
# # Lesson 11 Level 2 - Build a Short V2 Demo

# %% [markdown]
# ## Setup

# %%
from lesson_header import *
show_v2_status()
myRobot = bot(base_speed=280)

# %% [markdown]
# ## Variables and Functions
# Use the V2 object inside your own functions.

# %%
from lesson_header import *
myRobot = bot(base_speed=280)

move_time = 0.4

def demo_turn():
    myRobot.move.forward(move_time)
    myRobot.move.turn_right(move_time)

demo_turn()
myRobot.stop()

# %% [markdown]
# ## Loop Example

# %%
from lesson_header import *
myRobot = bot()
for i in range(3):
    myRobot.eyes.wink("left", blank_s=0.2)
myRobot.eyes.off()
