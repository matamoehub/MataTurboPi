# %% [markdown]
# # Lesson 11 — Level 2 (Two cups)
#
# This mirrors Lesson 1 Level 2 using the V2 object API.

# %% [markdown]
# ## Setup

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot(base_speed=280)

# %% [markdown]
# ## Movement tutorial
# Use short forward and turn tests to estimate how the robot will move around two cups.

# %%
from lesson_header import *
myRobot = bot(base_speed=280)
myRobot.move.forward(0.4)
myRobot.move.turn_right(0.3)
myRobot.stop()

# %% [markdown]
# ## Your two-cup plan
# Plan the sequence before you code it.
# - how will the robot pass cup 1?
# - what changes for cup 2?
# - which move needs the most tuning?

# %%
from lesson_header import *
myRobot = bot(base_speed=280)

# Build your two-cup route here.
# Use variables and one helper function if possible.
# myRobot.move.forward(...)
# myRobot.move.turn_left(...)
# myRobot.move.turn_right(...)
# myRobot.stop()
