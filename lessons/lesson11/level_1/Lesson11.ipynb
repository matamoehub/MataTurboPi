# %% [markdown]
# # Lesson 11 — Level 1 (Single cup)
#
# This is the V2 mirror of Lesson 1.
# Use one robot object and tune its movement around a single cup.

# %% [markdown]
# ## Setup
# Run this first.

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot(base_speed=300)

# %% [markdown]
# ## Example: a tiny test plan
# Use short movements first. Test one action at a time, then stop safely.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.move.forward(0.3)
time.sleep(0.2)
myRobot.move.turn_left(0.2)
myRobot.stop()

# %% [markdown]
# ## Challenge: Tune Drift Left (2 variables)
# Change the time and the `turn_blend` value. Observe how the robot curves around the cup.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.move.drift_left(0.8, turn_blend=0.55)
myRobot.stop()

# %% [markdown]
# ## Your plan (edit this)
# Write your own notes before you drive around the cup.
# - what move starts the path?
# - when will the robot turn?
# - where should it stop?

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

# Write your own single-cup plan here.
# myRobot.move.forward(...)
# myRobot.move.turn_left(...)
# myRobot.move.drift_left(...)
# myRobot.stop()
