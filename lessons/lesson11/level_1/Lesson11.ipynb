# %% [markdown]
# # Lesson 11 - Robot Demo V2
#
# Use one robot object for movement, eyes, sound, speech, and camera.

# %% [markdown]
# ## Setup
# Run this first.

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot(base_speed=300)

# %% [markdown]
# ## Movement
# The V2 movement API is under `myRobot.move`.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.move.forward(0.4)
time.sleep(0.3)
myRobot.move.turn_left(0.3)
myRobot.stop()

# %% [markdown]
# ## Eyes, Voice, and Horn

# %%
from lesson_header import *
myRobot = bot()
myRobot.eyes.color(0, 255, 120)
myRobot.eyes.wink("left", blank_s=0.3)
myRobot.voice.say("Hello, I am using robot version two.", block=True)
myRobot.horn()
myRobot.eyes.off()

# %% [markdown]
# ## Camera

# %%
from lesson_header import *
myRobot = bot()
myRobot.camera.left()
myRobot.camera.right()
myRobot.camera.center()
