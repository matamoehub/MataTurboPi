# %% [markdown]
# # Lesson 11 — Level 1 (Single cup)
#
# Goal: build an **algorithm** (a sequence of moves) to drive around **one cup**.
#
# You can use:
# - `myRobot.move.forward(seconds=...)`
# - `myRobot.move.backward(seconds=...)`
# - `myRobot.move.left(seconds=...)` / `myRobot.move.right(seconds=...)`
# - `myRobot.move.turn_left(seconds=...)` / `myRobot.move.turn_right(seconds=...)`
# - `drift_left(seconds)` / `drift_right(seconds)`
# - `horn()` (meep meep)
#
# ### Challenge
# Write a plan that avoids the cup **without touching it**.
#
# Tip: start slow. Then tighten it up.

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot(base_speed=300)

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print('Robot ready')

# %% [markdown]
# ## Example: a tiny test plan
# This is just to prove things move. You’ll write your own plan below.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

myRobot.horn()
myRobot.move.forward(0.5)
myRobot.stop()

# %% [markdown]
# ## Challenge: Tune Drift Left (2 variables)
# Use `myRobot.move.drift_left(seconds=..., turn_blend=...)`.
#
# - `seconds`: how long the drift runs
# - `turn_blend`: how curved the drift is (`0.0` = mostly sideways, `1.0` = strong turning arc)
#
# Your challenge is to test both variables and find your best drift settings around a cup.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

# Drift challenge: tune these two values
drift_seconds = 0.9
turn_blend = 0.55

print(f'Testing drift_left(seconds={drift_seconds}, turn_blend={turn_blend})')
myRobot.move.drift_left(seconds=drift_seconds, turn_blend=turn_blend)
myRobot.stop()

# %% [markdown]
# ## Your plan (edit this)
#
# Make a list of steps. Each step is ("move_name", seconds).
#
# Moves you can use as strings:
# `forward`, `backward`, `left`, `right`, `turn_left`, `turn_right`, `drift_left`, `drift_right`
#
# Then run the plan.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

# ============================
# YOUR PLAN (EDIT THIS)
# ============================

# Use these commands:

# myRobot.horn()
# myRobot.move.forward(0.5)
# myRobot.move.backward(0.5)
# myRobot.move.left(0.5)
# myRobot.move.right(0.5)
# myRobot.move.turn_left(0.5)
# myRobot.move.turn_right(0.5)
# myRobot.move.drift_left(0.5)
# myRobot.move.drift_right(0.5)
# myRobot.move.drift_right(0.5, turn_blend=0.55)  # drift with turn blend
# myRobot.stop()

# ----------------------------
# Write your moves below
# ----------------------------

# Example:
# myRobot.move.forward(0.7)
# myRobot.move.drift_left(0.8, turn_blend=0.55)
# myRobot.move.forward(0.4)
# myRobot.stop()
