# %% [markdown]
# # Robot Demo V2
#
# A short teacher demo showing one object controlling movement, eyes, camera, speech, and horn.
#
# This is the V2 mirror of the original Lesson 1 demo: one clear object, one consistent API.

# %%
from lesson_header import *
show_v2_status()
myRobot = bot(base_speed=300)

# %% [markdown]
# ## Demo idea
# Use this demo to show students that the V2 API groups robot actions together cleanly:
# - `myRobot.move`
# - `myRobot.eyes`
# - `myRobot.camera`
# - `myRobot.voice`
# - `myRobot.horn()`
#
# The teaching goal is not complexity. The teaching goal is consistency.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.eyes.set_both((0, 180, 255))
myRobot.voice.say('Hello, I am using the V2 robot object.')
myRobot.camera.shake()
myRobot.horn()
myRobot.stop()
