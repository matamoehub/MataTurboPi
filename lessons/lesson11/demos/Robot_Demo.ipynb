# %% [markdown]
# # Lesson 11 Demo - V2 Robot Performance

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.eyes.color(60, 180, 255)
myRobot.voice.say("Hi, I am Turbo version two.", block=True)
myRobot.move.forward(0.4)
myRobot.camera.left()
myRobot.move.drift_left(0.8, turn_blend=0.9)
myRobot.camera.right()
myRobot.move.drift_right(0.8, turn_blend=0.9)
myRobot.horn()
myRobot.stop()
myRobot.eyes.off()
