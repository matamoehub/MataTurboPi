# %% [markdown]
# # Level 2 - Autonomous Navigation
#
# Write a series of instructions that will allow your robot to make decisions and successfuly navigate an obstacle course using information from the robot sensors.
#
# While the obstacle course could be completed using a sequence of instructions like in level 1, the goal for this level is for your robot to recieve information and then change its behavior based on the information.
#
# A simplified example of this would be to continually drive forwards. If an object is detected, then turn left.
#
# For this task you will need to use:
#
# #### If statements
# If a given condition is true, execute the following code
# ```Python
# if condition:
#     print("true")
# ```
# #### If else statements
# If a given condition is true, execute the following code, if it is not true, execute the following code
# ```Python
# if true:
#     print("true")
# else
#     print("false")
# ```
# #### For loops
# Repeat the following code for every value i in given range
# ```Python
# for i in range(10):
#     print(i)
# ```
# #### While loops
# While condition is true, repeat the following code
# ```Python
# while true:
#     print("true")
# ```
# #### Methods that return values
# ```Python
# sonarDist = myRobot.sonar.distance_cm(filtered=True)
# ```
#
# ### Available commands:
#
# #### Sensor
# Returns the distance in cm to the nearest object in front of the robot, or `None` when nothing is in range. Always check for `None` before comparing the distance to a number.
# ```Python
# distance = myRobot.sonar.distance_cm(filtered=True)
# if distance is not None and distance < 20:
#     myRobot.stop()
# ```
# You can also ask directly whether something is close (this returns `False` when nothing is in range):
# ```Python
# if myRobot.sonar.is_closer_than(20):
#     myRobot.move.turn_left(0.4)
# ```
# The basic movement commands are also listed here.
#
# ```Python
# myRobot.move.forward(0.5)
# myRobot.move.backward(0.5)
# myRobot.move.left(0.5)
# myRobot.move.right(0.5)
#
# myRobot.move.turn_left(0.5)
# myRobot.move.turn_right(0.5)
#
# myRobot.move.drift_left(0.5, turn_blend=0.55)
# myRobot.move.drift_right(0.5, turn_blend=0.55)
#
# myRobot.stop()
# myRobot.horn()
# time.sleep(0.15)
# ```
#
# #### Remember to include the header file import and robot variable!
# ```Python
# from lesson_header import *
# myRobot = bot(base_speed=300)
# ```
# #### Write your moves in the cell below (Remember to add the import line and create your robot variable!)
