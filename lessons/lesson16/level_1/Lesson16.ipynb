# %% [markdown]
# # Lesson 16 - Project
#
# ## Scene
# Your robot is entering an obstacle-course challenge.
#
# It is not just trying to get through the course.
# It is also trying to perform.
#
# That means your code should make the robot feel creative and intentional:
# - movement should look planned
# - eyes should show state or mood
# - sounds and speech should add personality
# - the robot should react to obstacles, not ignore them

# %% [markdown]
# ## Project Goal
# Use these V2 namespaces together:
# - `myRobot.move`
# - `myRobot.eyes`
# - `myRobot.voice`
# - `myRobot.buzzer`
# - `myRobot.camera`
# - `myRobot.sonar`
#
# Your final code should help the robot navigate an obstacle course and react as it passes obstacles.

# %% [markdown]
# ## Coding Goals
# You should show each of these at least twice in your project:
# - variables
# - functions
# - loops
# - `if / else`
#
# Ideas:
# - use one variable for speed and another for obstacle count
# - write one function for obstacle celebration and another for obstacle recovery
# - use a `for` loop to iterate through eye colours
# - use a `while` loop to keep going around the cup multiple times

# %% [markdown]
# ## Setup
# Run this first.

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot(base_speed=300)

# %% [markdown]
# ## Library Area 1 - Movement
#
# Use `myRobot.move` for forward, turning, drifting, and stopping.
# Test these before you depend on them in the project.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.move.forward(0.3)
myRobot.move.turn_left(0.2)
myRobot.stop()

# %% [markdown]
# ## Library Area 2 - Eyes
#
# Use the eyes to show progress or mood.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.eyes.set_both((0, 120, 255))

# %% [markdown]
# ## Library Area 3 - TTS
#
# Use speech for short status updates.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.voice.say('Obstacle course ready.')

# %% [markdown]
# ## Library Area 4 - Buzzer
#
# Use short sounds as reactions or celebrations.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.buzzer.beep(note='C4', duration_s=0.2)

# %% [markdown]
# ## Library Area 5 - Camera
#
# Use camera movement to make the robot seem aware of the course.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.camera.look_left()
myRobot.camera.look_right()

# %% [markdown]
# ## Library Area 6 - Sonar
#
# Use sonar to decide how close the next obstacle is.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print(myRobot.sonar.distance_cm())

# %% [markdown]
# ## Progress idea: iterate through eye colours
#
# A good way to show iteration is to store eye colours in a list.
# Each obstacle passed can use the next colour in the list.
#
# You can also flash the eyes once for obstacle 1, twice for obstacle 2, and so on.
# That means one coding idea shows both progress and repetition.

# %% [markdown]
# ## Student Build Area
#
# Do not start with a huge script.
# Plan the flow first.
#
# Think about:
# - what happens when the path is clear
# - what happens when the robot gets close to an obstacle
# - how the robot celebrates progress
# - how the robot finishes the course
#
# Write the code in stages and test after each stage.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

# Build your project here.

myRobot.stop()
