# %% [markdown]
# # Lesson 16 - Project V2
#
# Use one robot object for movement, reaction, sound, and sonar.

# %% [markdown]
# ## Setup

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot(base_speed=260)

# %% [markdown]
# ## Planning Cell
# Before you code, decide what the robot should do, when it should react, and how it should show progress.

# %%
from lesson_header import *
myRobot = bot(base_speed=260)

# number_of_obstacles =
# warning_distance_cm =
# move_speed =
# eye_colours = [...]
# start_message =

# %% [markdown]
# ## Project Flow
# Keep this as pseudocode, not a copied solution.
#
# ```text
# START
# set up your variables
# set up your colours, sounds, or messages
#
# WHILE project not finished:
#     read sonar
#     decide what is happening
#     choose a move
#     react with eyes, sound, or speech
#     update progress
#
# STOP SAFELY
# ```

# %%
from lesson_header import *
myRobot = bot(base_speed=260)

# Build your own project here.
# myRobot.move.forward(...)
# myRobot.eyes.wink(...)
# myRobot.voice.say(...)
# myRobot.sonar.get_distance_cm(...)
# myRobot.stop()
