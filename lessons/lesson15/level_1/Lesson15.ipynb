# %% [markdown]
# # Lesson 15 — V2 Library Test Bench

# %% [markdown]
# ## Setup

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot()

# %% [markdown]
# ## 1. Robot Moves

# %%
from lesson_header import *
myRobot = bot()
myRobot.move.forward(0.2)
myRobot.stop()

# %% [markdown]
# ## 2. Eyes

# %%
from lesson_header import *
myRobot = bot()
myRobot.eyes.set_both(0, 255, 0)
time.sleep(0.3)
myRobot.eyes.off()

# %% [markdown]
# ## 3. Camera

# %%
from lesson_header import *
myRobot = bot()
myRobot.camera.nod()
myRobot.camera.center_all()

# %% [markdown]
# ## 4. Speech (TTS)

# %%
from lesson_header import *
myRobot = bot()
myRobot.voice.say("Testing V2 speech.", block=True)

# %% [markdown]
# ## 5. Buzzer

# %%
from lesson_header import *
myRobot = bot()
myRobot.buzzer.beep(note="C4", duration_s=0.15)

# %% [markdown]
# ## 6. Ultrasonic / Sonar

# %%
from lesson_header import *
myRobot = bot()
print(myRobot.sonar.distance_cm())

# %% [markdown]
# ## 7. Infrared Line Sensors

# %%
from lesson_header import *
myRobot = bot()
print(myRobot.infrared.read())

# %% [markdown]
# ## 8. PID Line Follower (Infrared)

# %%
from lesson_header import *
myRobot = bot()
print(type(myRobot.line.use_pid()).__name__ if myRobot.line.use_pid() is not None else None)

# %% [markdown]
# ## 9. ROS Line Following Node

# %%
from lesson_header import *
myRobot = bot()
print(type(myRobot.line.use_camera()).__name__ if myRobot.line.use_camera() is not None else None)

# %% [markdown]
# ## 10. Avoidance Node

# %%
from lesson_header import *
myRobot = bot()
print(myRobot.avoidance.ready())

# %% [markdown]
# ## 11. Object Tracking Node

# %%
from lesson_header import *
myRobot = bot()
print(myRobot.tracking.ready())

# %% [markdown]
# ## 12. QR Code Node

# %%
from lesson_header import *
myRobot = bot()
print(myRobot.qrcode.ready())

# %% [markdown]
# ## 13. Animation Library

# %%
from lesson_header import *
myRobot = bot()
print(type(myRobot.anim).__name__ if myRobot.anim is not None else None)

# %% [markdown]
# ## 14. Stop Everything

# %%
from lesson_header import *
myRobot = bot()
myRobot.stop()
