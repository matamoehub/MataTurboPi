# %% [markdown]
# # Lesson 15 - V2 Library Test Bench

# %% [markdown]
# ## Setup

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot()

# %% [markdown]
# ## Movement

# %%
from lesson_header import *
myRobot = bot()
myRobot.move.forward(0.2)
myRobot.stop()

# %% [markdown]
# ## Eyes

# %%
from lesson_header import *
myRobot = bot()
myRobot.eyes.color(0, 255, 0)
time.sleep(0.3)
myRobot.eyes.off()

# %% [markdown]
# ## Camera

# %%
from lesson_header import *
myRobot = bot()
myRobot.camera.nod()
myRobot.camera.center()

# %% [markdown]
# ## Voice and Buzzer

# %%
from lesson_header import *
myRobot = bot()
myRobot.voice.say("Testing version two.", block=True)
myRobot.buzzer.beep(note="C4", duration_s=0.15)

# %% [markdown]
# ## Sonar

# %%
from lesson_header import *
myRobot = bot()
print(myRobot.sonar.get_distance_cm(filtered=True))

# %% [markdown]
# ## Tracking / Avoidance / QR / Line

# %%
from lesson_header import *
myRobot = bot()
print("tracking ready:", myRobot.tracking.ready())
print("avoidance ready:", myRobot.avoidance.ready())
print("qrcode ready:", myRobot.qrcode.ready())
print("line backend:", type(myRobot.line.use_pid()).__name__ if myRobot.line.use_pid() is not None else None)
