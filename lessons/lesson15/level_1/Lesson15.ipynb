# %% [markdown]
# # Lesson 15 - Library Test Bench
#
# Use this notebook to test each robot library one at a time.
#
# Run any snippet cell independently. Each code cell starts by loading `lesson_header` again.

# %% [markdown]
# ## Setup
#
# Run this first when you open the notebook.

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot(base_speed=300)

# %% [markdown]
# ## 1. Robot Moves
#
# Use this to check that the motors respond.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

myRobot.move.forward(0.4)
time.sleep(0.3)
myRobot.move.backward(0.4)
time.sleep(0.3)
myRobot.stop()

# %% [markdown]
# ## 2. Eyes
#
# Use this to check the LED eyes.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

myRobot.eyes.set_both(0, 0, 255)
time.sleep(1.0)
myRobot.eyes.left(255, 0, 0)
time.sleep(1.0)
myRobot.eyes.right(0, 255, 0)
time.sleep(1.0)
myRobot.eyes.off()

# %% [markdown]
# ## 3. Camera
#
# Use this to check the camera pan/tilt movement.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

myRobot.camera.center_all()
myRobot.camera.glance_left()
myRobot.camera.glance_right()
myRobot.camera.look_down()
myRobot.camera.center_all()

# %% [markdown]
# ## 4. Speech (TTS)
#
# Use this to check speech output.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

myRobot.voice.say('Hello. This is a speech test.')

# %% [markdown]
# ## 5. Buzzer
#
# Use this to check the buzzer.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

myRobot.buzzer.beep(note='C4', duration_s=0.25)
time.sleep(0.2)
myRobot.buzzer.play_notes('C4:0.5 D4:0.5 E4:1')

# %% [markdown]
# ## 6. Ultrasonic / Sonar
#
# Use this to read the ultrasonic distance topic.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

print('waiting for sonar reading...')
print('distance mm:', myRobot.sonar.wait())
print('distance cm:', myRobot.sonar.distance_cm(filtered=True))

# %% [markdown]
# ## 7. Infrared Line Sensors
#
# Use this to inspect the 4 IR sensors.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print(myRobot.infrared)

# %% [markdown]
# ## 8. PID Line Follower (Infrared)
#
# This uses the local `LineFollower` class built on the infrared sensors.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print(myRobot.tracking)

# %% [markdown]
# ## 9. ROS Line Following Node
#
# This talks to the external `/line_following` ROS node.
# The node must already be running.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print(myRobot.avoidance)

# %% [markdown]
# ## 10. Avoidance Node
#
# This talks to the external `/avoidance_node` ROS node.
# The node must already be running.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print(myRobot.qrcode)

# %% [markdown]
# ## 11. Object Tracking Node
#
# This talks to the external `/object_tracking` ROS node.
# The node must already be running.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print(myRobot.anim)
myRobot.stop()

# %% [markdown]
# ## 12. QR Code Node
#
# This talks to the external `/qrcode` ROS node.
# The node must already be running.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

print('ready:', myRobot.qrcode.ready())
myRobot.qrcode.enter()
myRobot.qrcode.start_recognition(True)
myRobot.qrcode.start()
time.sleep(3.0)
myRobot.qrcode.stop()
myRobot.qrcode.exit()

# %% [markdown]
# ## 13. Animation Library
#
# This checks the student animation library.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

myRobot.anim.set_eye_color((0, 0, 255))
myRobot.anim.start_blinking(every_s=2.0, blank_s=0.5)
myRobot.anim.move('forward', seconds=0.4, speed=180)
myRobot.anim.speak('Animation library test.')
myRobot.stop()

# %% [markdown]
# ## 14. Stop Everything
#
# Use this if you want to quickly stop the robot after testing.

# %%
from lesson_header import *
stop_everything()
