# %% [markdown]
# # Lesson 15 - Library Test Bench
#
# Use this notebook to test each robot library one at a time.
#
# Run any snippet cell independently. Each code cell starts by loading `lesson_header` again so students can jump to any section.
#
# This is the V2 mirror of Lesson 5, but keeps the same testing purpose.

# %% [markdown]
# ## Setup
#
# Run this first when you open the notebook. Use the status output to see what loaded and what failed.

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot(base_speed=300)

# %% [markdown]
# ## 1. Robot Moves
#
# Use this to check that the motors respond.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.move.forward(0.3)
myRobot.move.backward(0.3)
myRobot.stop()

# %% [markdown]
# ## 2. Eyes
#
# Use this to check the LED eyes.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.eyes.set_both((255, 0, 0))
myRobot.eyes.wink('left')

# %% [markdown]
# ## 3. Camera
#
# Use this to check the camera pan/tilt movement.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.camera.look_left()
myRobot.camera.look_right()
myRobot.camera.center()

# %% [markdown]
# ## 4. Speech (TTS)
#
# Use this to check speech output.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.voice.say('Testing the V2 voice library.')

# %% [markdown]
# ## 5. Buzzer
#
# Use this to check the buzzer.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.buzzer.beep(note='C4', duration_s=0.2)

# %% [markdown]
# ## 6. Sonar
#
# Use this to check the ultrasonic distance reading.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print(myRobot.sonar.distance_cm())

# %% [markdown]
# ## 7. Infrared
#
# Use this to check the line/IR sensors if available.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print(myRobot.infrared)

# %% [markdown]
# ## 8. Tracking
#
# Use this to check tracking-related functions if the node is running.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print(myRobot.tracking)

# %% [markdown]
# ## 9. Avoidance
#
# Use this to check avoidance-related functions if the node is running.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print(myRobot.avoidance)

# %% [markdown]
# ## 10. QR Code
#
# Use this to check QR functionality if the node is running.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print(myRobot.qrcode)

# %% [markdown]
# ## 11. Animation
#
# Use this to check the higher-level animation helpers.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
print(myRobot.anim)
myRobot.stop()
