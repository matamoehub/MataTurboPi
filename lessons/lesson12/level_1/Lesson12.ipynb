# %% [markdown]
# # Lesson 12 - Character Animation V2

# %% [markdown]
# ## Setup

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot(base_speed=300)

# %% [markdown]
# ## Eyes and Blink

# %%
from lesson_header import *
myRobot = bot()
myRobot.eyes.color(0, 200, 255)
myRobot.eyes.blink_once(blank_s=0.5)
myRobot.eyes.wink("right", blank_s=0.4)
myRobot.eyes.off()

# %% [markdown]
# ## Voice

# %%
from lesson_header import *
myRobot = bot()
myRobot.voice.voices()
myRobot.voice.say("Animation version two is ready.", block=True)

# %% [markdown]
# ## Movement and Camera

# %%
from lesson_header import *
myRobot = bot(base_speed=280)
myRobot.move.forward(0.3)
myRobot.camera.shake()
myRobot.move.drift_left(0.8, turn_blend=0.95)
myRobot.stop()

# %% [markdown]
# ## Full Demo

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.anim.demo_turbo_sequence()
