# %% [markdown]
# # Lesson 12 — Character Animation (Level 2) With V2

# %% [markdown]
# ## Step 1 — Configure character
# Choose eye colour, voice, and pacing.

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot(base_speed=300)
# myRobot.eyes.color(...)
# myRobot.voice.select_voice(number=1)

# %% [markdown]
# ## Step 2 — Build your sequence function
# Wrap your animation into one function so you can replay it.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

# def my_sequence():
#     ...

# %% [markdown]
# ## Step 3 — Student challenge edits
# Improve the timing, acting, and ending move.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
# Edit and run your own sequence here.
