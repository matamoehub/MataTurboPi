# %% [markdown]
# # Lesson 12 Level 2 - Build Your Own Animation V2

# %% [markdown]
# ## Setup

# %%
from lesson_header import *
show_v2_status()
myRobot = bot(base_speed=300)

# %% [markdown]
# ## Planning Prompt
# Choose the order of movement, eyes, camera, and voice. Use the V2 namespaces instead of separate libraries.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)

# Build your own sequence here.
# myRobot.move.forward(...)
# myRobot.eyes.wink(...)
# myRobot.camera.shake(...)
# myRobot.voice.say(...)
# myRobot.horn()
# myRobot.stop()
