# %% [markdown]
# # Lesson 14 — Robot Animation (Personality)
#
# Goal:
# - give the robot character
# - use camera moves + eyes
# - use speech via the V2 voice namespace
#
# No navigation. No sensors.
#
# This lesson is about performance, mood, and timing.

# %%
from lesson_header import *
show_v2_status()
myRobot = bot(base_speed=300)

# %% [markdown]
# ## Build some expressions
#
# These are your animation building blocks.
# Test them separately first so you know what each action feels like.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
myRobot.eyes.wink('left')
myRobot.camera.nod()
myRobot.voice.say('Hello there.')

# %% [markdown]
# ## Personality loop
#
# Run a simple mood machine for 20 seconds.
#
# The goal is not random noise. The goal is to make the robot seem alive in a deliberate way.

# %%
from lesson_header import *
myRobot = bot(base_speed=300)
# Build a short repeating personality loop here.

# %% [markdown]
# ## Design questions
#
# Think about:
# - what makes the robot seem calm
# - what makes it seem excited
# - how much speech is too much
# - how much movement is too much
#
# Good animation is often about restraint, not maximum activity.
