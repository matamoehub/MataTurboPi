# %% [markdown]
# # Lesson 14 - Robot Personality V2

# %% [markdown]
# ## Setup

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot()

# %% [markdown]
# ## Personality Building Blocks

# %%
from lesson_header import *
myRobot = bot()
myRobot.eyes.color(255, 120, 0)
myRobot.camera.nod()
myRobot.voice.say("I am thinking.", block=True)
myRobot.eyes.off()

# %% [markdown]
# ## Reactions

# %%
from lesson_header import *
myRobot = bot()
myRobot.camera.left()
myRobot.camera.right()
myRobot.camera.shake()
myRobot.horn()
