# %% [markdown]
# # Lesson 14 — Robot Animation (Personality) With V2

# %% [markdown]
# ## Setup

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot()

# %% [markdown]
# ## Build some expressions
# Use eyes, camera, speech, and movement to create a few clear robot moods.

# %%
from lesson_header import *
myRobot = bot()
myRobot.eyes.color(255, 120, 0)
myRobot.camera.nod()
myRobot.voice.say("I am thinking.", block=True)
myRobot.eyes.off()

# %% [markdown]
# ## Personality loop
# Design a short repeating loop that makes the robot feel alive without spamming speech.

# %%
from lesson_header import *
myRobot = bot()
# Build your own personality loop here.
# Use blink, movement, camera, and short speech carefully.
