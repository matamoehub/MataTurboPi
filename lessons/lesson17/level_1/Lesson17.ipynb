# %% [markdown]
# # Lesson 17 — Advanced Project With V2

# %% [markdown]
# ## Project Goal
# Use the V2 object and its sensors to build a stronger autonomous obstacle-course robot.

# %% [markdown]
# ## Advanced Coding Goals
# Use variables, return-value functions, dictionary lookups, loops, conditionals, and a class structure.

# %% [markdown]
# ## Setup

# %%
from lesson_header import *
show_v2_status()
show_v2_versions()
myRobot = bot(base_speed=260)

# %% [markdown]
# ## Library Check
# Confirm which V2 namespaces and backends are ready before building anything.

# %%
from lesson_header import *
myRobot = bot()
show_v2_status()

# %% [markdown]
# ## Sonar Test
# Start with the most important sensor for this project.
#
# Questions to investigate:
# - What reading do you get when the path is clear?
# - What reading do you get when a cup is close?
# - What reading should count as `warning`?
# - What reading should count as `blocked`?

# %%
from lesson_header import *
myRobot = bot()
for i in range(10):
    print(myRobot.sonar.distance_cm())
    time.sleep(0.5)

# %% [markdown]
# ## Movement Test
# Test short moves one at a time. Learn how far the robot travels and how much space each move needs.

# %%
from lesson_header import *
myRobot = bot(base_speed=260)
# myRobot.move.forward(0.2)
# myRobot.move.turn_left(0.2)
# myRobot.move.turn_right(0.2)
# myRobot.move.backward(0.2)

# %% [markdown]
# ## Eyes Test
# Use eye colours to show robot state.

# %%
from lesson_header import *
myRobot = bot()
# myRobot.eyes.set_both(0,255,0)
# time.sleep(0.5)
# myRobot.eyes.off()

# %% [markdown]
# ## Camera Test
# Use the camera to show the robot's decisions or reactions.

# %%
from lesson_header import *
myRobot = bot()
# myRobot.camera.glance_left()
# myRobot.camera.glance_right()
# myRobot.camera.center_all()

# %% [markdown]
# ## Voice And Buzzer Test
# Use sound to announce state changes or warnings.

# %%
from lesson_header import *
myRobot = bot()
# myRobot.voice.say("Sensor test complete.", block=True)
# myRobot.buzzer.beep(note="C4", duration_s=0.15)

# %% [markdown]
# ## Planning With Pseudocode
#
# ```text
# WHILE ...:
#     read sensor
#     decide state (how close am I )
#     choose action ie which move
#     recover if needed
#     update progress
# ```
#
# Use that flow as a guide, then add your own thresholds, states, and recovery ideas.

# %% [markdown]
# ## Design Questions
# - Which function should return the current robot state?
# - Which function should return the next action?
# - Which dictionary could map states to colours or sounds?
# - Which loop should keep the robot making decisions?
# - How will the robot detect that it has passed an obstacle?

# %% [markdown]
# ## Student Build Area
# Build your own advanced obstacle-course program here.

# %%
from lesson_header import *
myRobot = bot(base_speed=260)

# Variables
# warning_distance_cm =
# blocked_distance_cm =
# obstacles_passed =
# current_state =

# Dictionary ideas
# state_colours = {...}
# state_messages = {...}

# Functions that return values
# def read_distance_cm():
#     return ...
#
# def classify_distance(distance_cm):
#     return ...
#
# def choose_action(state):
#     return ...

# Class idea
# class CourseRobot:
#     ...

# Main loop idea
# while ...:
#     read sensor
#     decide state (how close am I )
#     choose action ie which move
#     recover if needed
#     update progress

# %% [markdown]
# ## Final Reminder
# A strong advanced project should show that you tested sensors first, designed your own algorithm, used structured code, and can explain the robot's decisions.
