# %% [markdown]
# # Lesson 17 - Advanced Project V2

# %% [markdown]
# ## Setup

# %%
from lesson_header import *
show_v2_status()
myRobot = bot(base_speed=260)

# %% [markdown]
# ## Test First
# Use the V2 object to test sensor values and robot responses before writing the full program.

# %%
from lesson_header import *
myRobot = bot()
for i in range(10):
    print(myRobot.sonar.get_distance_cm(filtered=True))
    time.sleep(0.5)

# %% [markdown]
# ## Main Flow Idea
#
# ```text
# WHILE ...:
#     read sensor
#     decide state (how close am I )
#     choose action ie which move
#     recover if needed
#     update progress
# ```

# %% [markdown]
# ## Build Area
# Use dictionaries, functions that return values, and class structure, but do not copy a completed solution.

# %%
from lesson_header import *
myRobot = bot(base_speed=260)

# Variables
# warning_distance_cm =
# blocked_distance_cm =
# obstacles_passed =
# current_state =

# Dictionary ideas
# state_colours = {...}
# state_messages = {...}

# Functions that return values
# def read_distance_cm():
#     return ...
#
# def classify_distance(distance_cm):
#     return ...
#
# def choose_action(state):
#     return ...

# Class idea
# class CourseRobot:
#     ...

# Main loop idea
# while ...:
#     read sensor
#     decide state (how close am I )
#     choose action ie which move
#     recover if needed
#     update progress
