# %% [markdown]
# # Lesson 10 - Workspace
#
# This notebook is a workspace for trying the V2 robot library.
#
# Use it to:
# - test commands
# - check sensors
# - try camera and vision code
# - build small ideas before putting them into another lesson

# %% [markdown]
# ## Start The Robot

# %%
from lesson_header import *

show_v2_status()
myRobot = bot(base_speed=300, verbose=False)

# %% [markdown]
# ## Safety Stop
#
# Run this if you want to stop the robot.

# %%
myRobot.stop()

# %% [markdown]
# ## Movement Workspace

# %%
# Try one command at a time.
# myRobot.move.forward(seconds=0.5, speed=100)
# myRobot.move.backward(seconds=0.5, speed=100)
# myRobot.move.left(seconds=0.5, speed=100)
# myRobot.move.right(seconds=0.5, speed=100)
# myRobot.move.turn_left(seconds=0.5, speed=100)
# myRobot.move.turn_right(seconds=0.5, speed=100)
# myRobot.move.diagonal_left(seconds=0.8, speed=100)
# myRobot.move.diagonal_right(seconds=0.8, speed=100)
# myRobot.move.drift_left(seconds=1.0, speed=100, turn_blend=0.55)
# myRobot.move.drift_right(seconds=1.0, speed=100, turn_blend=0.55)

myRobot.stop()

# %% [markdown]
# ## Eyes And Camera Workspace

# %%
# Eyes examples
# myRobot.eyes.on(0, 255, 0)
# myRobot.eyes.left(255, 0, 0)
# myRobot.eyes.right(0, 0, 255)
# myRobot.eyes.blink_once(blank_s=0.2)

# Camera examples
# myRobot.camera.center_all()
# myRobot.camera.left(amplitude=250, hold_s=0.0)
# myRobot.camera.right(amplitude=250, hold_s=0.0)
# myRobot.camera.look_down(amplitude=200, hold_s=0.0)
# myRobot.camera.nod(depth=250, speed_s=0.15)

pass

# %% [markdown]
# ## Sound Workspace

# %%
# myRobot.voice.say("Hello")
# myRobot.voice.set_volume(60)
# myRobot.buzzer.horn()
# myRobot.buzzer.beep()

pass

# %% [markdown]
# ## Sonar Workspace

# %%
distance_cm = myRobot.sonar.distance_cm()
distance_mm = myRobot.sonar.distance_mm()

print("cm:", distance_cm)
print("mm:", distance_mm)
print("closer than 20 cm:", myRobot.sonar.is_closer_than(20))

# %% [markdown]
# ## Vision Workspace

# %%
# Camera capture
picture = myRobot.vision.capture()
print(picture["path"])

# %%
# Colour profile example
# myRobot.vision.set_color_profile(
#     "green",
#     lower_hsv=(47, 98, 98),
#     upper_hsv=(71, 238, 238),
# )
# myRobot.vision.show_color("green")

pass

# %%
# Direction decision example
# decision = myRobot.vision.target_position("green", deadzone=50, show=True)
# print(decision)

pass

# %% [markdown]
# ## Service Workspace

# %%
# These depend on the robot services being available.
# line = myRobot.line.use_pid()
# line.start()
# line.stop()
#
# myRobot.tracking.set_color_name("green")
# myRobot.tracking.start()
# myRobot.tracking.stop()
#
# myRobot.avoidance.start()
# myRobot.avoidance.stop()
#
# myRobot.qrcode.start()
# myRobot.qrcode.stop()

pass

# %% [markdown]
# ## Notes
#
# - Use this notebook to test small ideas.
# - Copy finished code into your lesson notebook when it works.
# - Use `myRobot.stop()` whenever you need a quick stop.
