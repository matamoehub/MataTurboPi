# %% [markdown]
# # Lesson 2 — Character Animation (Level 1)
#
# In this level you run examples with `student_animation_lib`.
# You will combine movement, eyes, camera gestures, and speech.

# %%
from lesson_header import *
import student_animation_lib as al
import importlib
importlib.reload(al)

anim = al.get_animation_lib(base_speed=300)
print('student_animation_lib ready:', al.__file__)

# %% [markdown]
# ## Example 1 — Async move + blink
#
# Blinking runs in the background while the robot moves.

# %%
anim.set_eye_color((0, 180, 255))
anim.start_blinking(every_s=2.5, blank_s=0.5)
anim.move_async('forward', seconds=1.0, speed=180)
anim.move('backward', seconds=0.8, speed=160)
anim.stop_blinking()

# %% [markdown]
# ## Example 2 — Wink + camera gestures

# %%
anim.set_eye_color((255, 160, 60))
anim.wink('left', blank_s=0.5)
anim.wink('right', blank_s=0.5)
anim.nod(depth=220)
anim.shake(width=220)
anim.look_up(amplitude=220)
anim.look_left(amplitude=220)
anim.look_down(amplitude=220)
anim.look_right(amplitude=220)
anim.center_camera()

# %% [markdown]
# ## Example 3 — Voice selection + phrase cache
#
# Generate phrases once, then play quickly from cache.

# %%
anim.select_voice('ryan')
anim.generate_phrase('intro', 'Hi, I am Turbo. Nice to meet you.')
anim.generate_phrase('line', 'I am ready to perform my animation sequence.')
anim.play_phrase('intro', block=True)
anim.play_phrase('line', block=True)

# %% [markdown]
# ## Example 4 — Testable fidget plan
#
# `build_fidget_plan` gives deterministic random moves with a seed.

# %%
plan = al.build_fidget_plan(duration_s=1.0, step_s=0.05, seed=7)
print('fidget steps:', len(plan))
print('first 12:', plan[:12])
anim.do_fidget(duration_s=1.0, step_s=0.05, speed_scale=0.25, seed=7)

# %% [markdown]
# ## Demo — Turbo character sequence
#
# Requested demo:
# - speech line
# - fidget + blink while talking
# - look left then right
# - shake on sigh
# - drift left then right (`turn_blend=0.95`)

# %%
anim.demo_turbo_sequence()

# %%
# Optional: horn at the end
anim.horn_normal()
