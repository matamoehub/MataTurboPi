# %% [markdown]
# # Lesson 2 — Character Animation (Level 1)
#
# This lesson is built so students can start from any code cell.
# Each example cell re-imports `lesson_header` and validates `anim`.

# %%
from lesson_header import *
show_lesson_status()

# %% [markdown]
# ## Demo First — Turbo Character Sequence
#
# Run this first to see the target outcome.

# %%
from lesson_header import *

if anim is None:
    raise RuntimeError("Animation library did not load. Run show_lesson_status()")
anim.demo_turbo_sequence()

# %% [markdown]
# ## Async vs Sync Quick Guide
#
# - `anim.move(...)` waits until complete (**sync**)
# - `anim.move_async(...)` starts and returns immediately (**async**)
# - `anim.start_blinking(...)` runs in background (**async**)
# - `anim.start_fidget(...)` runs in background (**async**)
# - `anim.play_phrase(..., block=True)` waits (**sync**)
# - `anim.play_phrase(..., block=False)` does not wait (**async**)

# %% [markdown]
# ## Example 1 — Async move + blink

# %%
from lesson_header import *

if anim is None:
    raise RuntimeError("Animation library did not load. Run show_lesson_status()")
anim.set_eye_color((0, 180, 255))
anim.start_blinking(every_s=2.5, blank_s=0.5)
anim.move_async('forward', seconds=1.0, speed=140)
anim.move('backward', seconds=0.8, speed=120)
anim.stop_blinking()

# %% [markdown]
# ## Example 2 — Wink + camera gestures

# %%
from lesson_header import *

if anim is None:
    raise RuntimeError("Animation library did not load. Run show_lesson_status()")
anim.set_eye_color((255, 160, 60))
anim.wink('left', blank_s=0.5)
anim.wink('right', blank_s=0.5)
anim.nod(depth=220)
anim.shake(width=220)
anim.look_up(amplitude=220)
anim.look_left(amplitude=220)
anim.look_down(amplitude=220)
anim.look_right(amplitude=220)
anim.center_camera()

# %% [markdown]
# ## Example 3 — Voice selection + phrase cache

# %%
from lesson_header import *

if anim is None:
    raise RuntimeError("Animation library did not load. Run show_lesson_status()")
anim.select_voice('ryan')
anim.generate_phrase('intro', 'Hi, I am Turbo. Nice to meet you.')
anim.generate_phrase('line', 'I am ready to perform my animation sequence.')
anim.play_phrase('intro', block=True)
anim.play_phrase('line', block=True)

# %% [markdown]
# ## Example 4 — Buzzer reactions
#
# Use `bz` from `lesson_header`.

# %%
from lesson_header import *

if bz is None:
    raise RuntimeError("Buzzer library did not load")

# Short reaction beeps
bz.beep(1800, 0.10)
time.sleep(0.10)
bz.beep(2200, 0.12)

# Melody fragment
bz.play_notes("C5:0.5 E5:0.5 G5:0.5 R:0.3 G5:0.5", bpm=140)

# %% [markdown]
# ## Example 5 — Testable fidget plan

# %%
from lesson_header import *

if anim is None:
    raise RuntimeError("Animation library did not load. Run show_lesson_status()")
plan = al.build_fidget_plan(duration_s=1.0, step_s=0.05, seed=7)
print('fidget steps:', len(plan))
print('first 12:', plan[:12])
anim.do_fidget(duration_s=1.0, step_s=0.05, speed_scale=0.12, seed=7)

# %%
from lesson_header import *

if anim is None:
    raise RuntimeError("Animation library did not load. Run show_lesson_status()")
# Optional: horn at the end
anim.horn_normal()
