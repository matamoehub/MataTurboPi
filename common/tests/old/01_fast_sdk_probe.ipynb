# %% [markdown]
# # Test 01 — fast_sdk probe
#
# Checks:
# - repo path bootstrap
# - fast_sdk package + submodules
# - core class imports and basic instantiation

# %%
# --- Bootstrap: add repo root + common/lib to sys.path ---
from pathlib import Path
import sys

def add_repo_to_path():
    here = Path.cwd().resolve()
    for p in [here] + list(here.parents):
        if (p / 'lessons').is_dir() and (p / 'common').is_dir():
            repo_root = p
            common_lib = p / 'common' / 'lib'
            if str(repo_root) not in sys.path:
                sys.path.insert(0, str(repo_root))
            if str(common_lib) not in sys.path:
                sys.path.insert(0, str(common_lib))
            print('Repo root:', repo_root)
            print('Added common/lib:', common_lib)
            return repo_root
    raise FileNotFoundError('Could not find repo root (needs lessons/ and common/)')

add_repo_to_path()

# %%
import sys
print('Python:', sys.version)
print('sys.path[0:6]:')
for p in sys.path[:6]:
    print('  ', p)

# %%
import pkgutil
import fast_sdk

print('fast_sdk:', fast_sdk.__file__)
print('submodules:', [m.name for m in pkgutil.iter_modules(fast_sdk.__path__)])

# %%
from fast_sdk.motors import ControlChassis
from fast_sdk.infra_red import InfraredSensors
from fast_sdk.board_sdk import BoardSDK

chassis = ControlChassis()
ir = InfraredSensors()
board = BoardSDK()

print('OK ControlChassis:', chassis)
print('OK InfraredSensors:', ir, 'default addr:', hex(ir.address))
print('OK BoardSDK:', board)

print('BoardSDK candidate methods:', [n for n in dir(board) if any(k in n.lower() for k in ('buzzer','led','rgb'))])
