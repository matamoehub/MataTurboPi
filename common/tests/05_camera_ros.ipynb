# %% [markdown]
# # Test 05 — Camera (ROS) via camera_lib
#
# Requires:
# - rclpy import works in this kernel
# - ros_robot_controller_msgs available
# - ros_move running (or whichever node subscribes to pwm_servo)

# %%
# --- Bootstrap: add repo root + common/lib to sys.path ---
from pathlib import Path
import sys

def add_repo_to_path():
    here = Path.cwd().resolve()
    for p in [here] + list(here.parents):
        if (p / 'lessons').is_dir() and (p / 'common').is_dir():
            repo_root = p
            common_lib = p / 'common' / 'lib'
            if str(repo_root) not in sys.path:
                sys.path.insert(0, str(repo_root))
            if str(common_lib) not in sys.path:
                sys.path.insert(0, str(common_lib))
            print('Repo root:', repo_root)
            print('Added common/lib:', common_lib)
            return repo_root
    raise FileNotFoundError('Could not find repo root (needs lessons/ and common/)')

add_repo_to_path()

# %%
import sys
print('Python:', sys.version)

try:
    import rclpy
    print('rclpy OK:', rclpy.__file__)
except Exception as e:
    raise RuntimeError('rclpy not available in this kernel. Start Jupyter in ROS env.') from e

try:
    import ros_robot_controller_msgs
    print('ros_robot_controller_msgs OK:', ros_robot_controller_msgs.__file__)
except Exception as e:
    raise RuntimeError('ros_robot_controller_msgs not available in this kernel.') from e

# %%
import camera_lib
cam = camera_lib.get_camera()
print('Camera instance:', cam)

print('Center...')
cam.center_all()

print('Nod...')
cam.nod(depth=220, speed_s=0.15)

print('Shake...')
cam.shake(width=220, speed_s=0.15)

print('Wiggle...')
cam.wiggle(cycles=1, amplitude=160, speed_s=0.12)

print('Center...')
cam.center_all()
print('Done')
