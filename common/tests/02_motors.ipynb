# %% [markdown]
# # Test 02 — Motors movement
#
# Does: forward / back / turn left / turn right / stop.
# Keep robot lifted or on clear floor.

# %%
# --- Bootstrap: add repo root + common/lib to sys.path ---
from pathlib import Path
import sys

def add_repo_to_path():
    here = Path.cwd().resolve()
    for p in [here] + list(here.parents):
        if (p / 'lessons').is_dir() and (p / 'common').is_dir():
            repo_root = p
            common_lib = p / 'common' / 'lib'
            if str(repo_root) not in sys.path:
                sys.path.insert(0, str(repo_root))
            if str(common_lib) not in sys.path:
                sys.path.insert(0, str(common_lib))
            print('Repo root:', repo_root)
            print('Added common/lib:', common_lib)
            return repo_root
    raise FileNotFoundError('Could not find repo root (needs lessons/ and common/)')

add_repo_to_path()

# %%
import time
from fast_sdk.motors import ControlChassis

ch = ControlChassis()

def stop():
    ch.set_velocity(0, 0, 0)

def forward(secs=0.5, speed=80):
    ch.set_velocity(speed, 0, 0)
    time.sleep(secs)
    stop()

def back(secs=0.5, speed=80):
    ch.set_velocity(speed, 180, 0)
    time.sleep(secs)
    stop()

def turn_left(secs=0.4, rate=40):
    ch.set_velocity(0, 0, +rate)
    time.sleep(secs)
    stop()

def turn_right(secs=0.4, rate=40):
    ch.set_velocity(0, 0, -rate)
    time.sleep(secs)
    stop()

print('Forward')
forward()
time.sleep(0.3)

print('Back')
back()
time.sleep(0.3)

print('Turn left')
turn_left()
time.sleep(0.3)

print('Turn right')
turn_right()
time.sleep(0.3)

print('Done')
