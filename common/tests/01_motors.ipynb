# %% [markdown]
# # Test 01 — Motors / Movement (ROS cmd_vel)
#
# Runs a short movement sequence (forward, stop, turn, stop).
# Keep the robot on blocks or with wheels clear for first run.

# %%
from pathlib import Path
import sys

def add_repo_to_path():
    here = Path.cwd().resolve()
    for p in [here] + list(here.parents):
        if (p / 'lessons').is_dir() and (p / 'common').is_dir():
            repo_root = p
            common_lib = p / 'common' / 'lib'
            if str(repo_root) not in sys.path:
                sys.path.insert(0, str(repo_root))
            if str(common_lib) not in sys.path:
                sys.path.insert(0, str(common_lib))
            print('Repo root:', repo_root)
            print('Added common/lib:', common_lib)
            return
    raise FileNotFoundError('Could not find repo root (needs lessons/ and common/)')

add_repo_to_path()

# %%
import time
from robot_moves import RobotMoves

rm = RobotMoves()
print('RobotMoves ready')

print('Forward 0.15 m/s for 1.0s')
rm.drive_for(0.15, 0.0, 1.0)
time.sleep(0.5)

print('Turn left in place for 0.8s')
rm.drive_for(0.0, 1.0, 0.8)
time.sleep(0.5)

print('Forward gentle curve for 1.5s')
rm.drive_for(0.15, 0.35, 1.5)

print('Stop')
rm.stop()
print('Done')
