# %% [markdown]
# # Test 05 — Text to Speech
#
# Basic sanity check for your `tts_lib` wrapper.
# Goal: generate audio + play it.

# %%
from pathlib import Path
import sys

def add_repo_to_path():
    here = Path.cwd().resolve()
    for p in [here] + list(here.parents):
        if (p / 'lessons').is_dir() and (p / 'common').is_dir():
            repo_root = p
            common_lib = p / 'common' / 'lib'
            if str(repo_root) not in sys.path:
                sys.path.insert(0, str(repo_root))
            if str(common_lib) not in sys.path:
                sys.path.insert(0, str(common_lib))
            print('Repo root:', repo_root)
            print('Added common/lib:', common_lib)
            return
    raise FileNotFoundError('Could not find repo root (needs lessons/ and common/)')

add_repo_to_path()

# %%
import tts_lib

print('tts_lib:', tts_lib)
print('Functions:', [n for n in dir(tts_lib) if 'say' in n.lower() or 'tts' in n.lower() or 'speak' in n.lower()])

# %%
# Common patterns we try. Adjust once we see your exact tts_lib API.
text = "Kia ora. Text to speech test."

if hasattr(tts_lib, 'say'):
    tts_lib.say(text)
    print('OK: tts_lib.say(text)')
elif hasattr(tts_lib, 'speak'):
    tts_lib.speak(text)
    print('OK: tts_lib.speak(text)')
else:
    raise RuntimeError('Could not find say() or speak() in tts_lib. Paste dir(tts_lib) and I will lock it down.')
