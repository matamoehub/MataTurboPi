# %% [markdown]
# # Test 04 — Eyes (RGB)\n\nGoal: find which topic + indices control the eye LEDs.\n1) Diagnose topics\n2) Scan indices (you watch the robot)\n3) Set known indices + blink\n

# %%
from pathlib import Path
import sys

def add_repo_to_path():
    here = Path.cwd().resolve()
    for p in [here] + list(here.parents):
        if (p / 'lessons').is_dir() and (p / 'common').is_dir():
            repo_root = p
            common_lib = p / 'common' / 'lib'
            if str(common_lib) not in sys.path:
                sys.path.insert(0, str(common_lib))
            print('Repo root:', repo_root)
            print('Added common/lib:', common_lib)
            return repo_root
    raise FileNotFoundError('Could not find repo root (needs lessons/ and common/)')

add_repo_to_path()

# %%
import time
import eyes_lib

eyes = eyes_lib.get_eyes()
eyes.diagnose()

print('Scanning indices 0..16 in blue. Watch for the eye LEDs...')
eyes.scan_indices(0, 16, color=(0,0,255), hold_s=0.35)

print('If you saw the eyes light up at some indices, set them in get_eyes(indices=(L,R))')

# %%
# Once you know the correct indices, set them here and re-run
import importlib
importlib.reload(eyes_lib)

eyes = eyes_lib.get_eyes(indices=(0,1))  # TODO: change after scan
print('Blinking white for 2s...')
eyes.blink(color=(255,255,255), period_s=0.25, duration_s=2.0)
eyes.off()
print('Done')
